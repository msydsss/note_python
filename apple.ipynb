# %%
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout
from keras.utils.np_utils import to_categorical
from keras.optimizers import Adagrad
from keras.optimizers import Adam
import numpy as np
from PIL import Image
import os
import shutil
# Out:
# Using TensorFlow backend.

# %%
image_list = []
label_list = []

# %%
for dir in os.listdir("C:/Users/user/Desktop/train"):
    dir1 = "C:/Users/user/Desktop/train/" + dir 
    label = 0
    
    if dir == "学習用りんご画像":
        label = 0
    elif dir == "学習用梨画像":
        label = 1
    for file in os.listdir(dir1):
        # 配列label_listに正解ラベルを追加(りんご:0 オレンジ:1)
        label_list.append(label)
        filepath = dir1 + "/" + file
        # 画像を25x25pixelに変換し、1要素が[R,G,B]3要素を含む配列の25x25の２次元配列として読み込む。
        # [R,G,B]はそれぞれが0-255の配列。
        image = np.array(Image.open(filepath).resize((25, 25)))
        # 配列を変換し、[[Redの配列],[Greenの配列],[Blueの配列]] のような形にする。
        image = image.transpose(2, 0, 1)
        # さらにフラットな1次元配列に変換。最初の1/3はRed、次がGreenの、最後がBlueの要素がフラットに並ぶ。
        image = image.reshape(1, image.shape[0] * image.shape[1] * image.shape[2]).astype("float32")[0]
        # 出来上がった配列をimage_listに追加。
        image_list.append(image / 255.)
        print(image_list)
# Out:
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32), array([0.16862746, 0.14509805, 0.17254902, ..., 0.10588235, 0.10588235,
#        0.10588235], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32), array([0.16862746, 0.14509805, 0.17254902, ..., 0.10588235, 0.10588235,
#        0.10588235], dtype=float32), array([0.01176471, 0.01176471, 0.01176471, ..., 0.11372549, 0.1254902 ,
#        0.16862746], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32), array([0.16862746, 0.14509805, 0.17254902, ..., 0.10588235, 0.10588235,
#        0.10588235], dtype=float32), array([0.01176471, 0.01176471, 0.01176471, ..., 0.11372549, 0.1254902 ,
#        0.16862746], dtype=float32), array([0.2509804 , 0.24705882, 0.23137255, ..., 0.44705883, 0.44705883,
#        0.41568628], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32), array([0.16862746, 0.14509805, 0.17254902, ..., 0.10588235, 0.10588235,
#        0.10588235], dtype=float32), array([0.01176471, 0.01176471, 0.01176471, ..., 0.11372549, 0.1254902 ,
#        0.16862746], dtype=float32), array([0.2509804 , 0.24705882, 0.23137255, ..., 0.44705883, 0.44705883,
#        0.41568628], dtype=float32), array([0.        , 0.9098039 , 0.8627451 , ..., 0.05490196, 0.05490196,
#        0.05490196], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32), array([0.16862746, 0.14509805, 0.17254902, ..., 0.10588235, 0.10588235,
#        0.10588235], dtype=float32), array([0.01176471, 0.01176471, 0.01176471, ..., 0.11372549, 0.1254902 ,
#        0.16862746], dtype=float32), array([0.2509804 , 0.24705882, 0.23137255, ..., 0.44705883, 0.44705883,
#        0.41568628], dtype=float32), array([0.        , 0.9098039 , 0.8627451 , ..., 0.05490196, 0.05490196,
#        0.05490196], dtype=float32), array([0.28627452, 0.19607843, 0.26666668, ..., 0.16862746, 0.16078432,
#        0.15686275], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32), array([0.16862746, 0.14509805, 0.17254902, ..., 0.10588235, 0.10588235,
#        0.10588235], dtype=float32), array([0.01176471, 0.01176471, 0.01176471, ..., 0.11372549, 0.1254902 ,
#        0.16862746], dtype=float32), array([0.2509804 , 0.24705882, 0.23137255, ..., 0.44705883, 0.44705883,
#        0.41568628], dtype=float32), array([0.        , 0.9098039 , 0.8627451 , ..., 0.05490196, 0.05490196,
#        0.05490196], dtype=float32), array([0.28627452, 0.19607843, 0.26666668, ..., 0.16862746, 0.16078432,
#        0.15686275], dtype=float32), array([0.00392157, 0.        , 0.5803922 , ..., 0.05490196, 0.05490196,
#        0.05882353], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32), array([0.16862746, 0.14509805, 0.17254902, ..., 0.10588235, 0.10588235,
#        0.10588235], dtype=float32), array([0.01176471, 0.01176471, 0.01176471, ..., 0.11372549, 0.1254902 ,
#        0.16862746], dtype=float32), array([0.2509804 , 0.24705882, 0.23137255, ..., 0.44705883, 0.44705883,
#        0.41568628], dtype=float32), array([0.        , 0.9098039 , 0.8627451 , ..., 0.05490196, 0.05490196,
#        0.05490196], dtype=float32), array([0.28627452, 0.19607843, 0.26666668, ..., 0.16862746, 0.16078432,
#        0.15686275], dtype=float32), array([0.00392157, 0.        , 0.5803922 , ..., 0.05490196, 0.05490196,
#        0.05882353], dtype=float32), array([0.00784314, 0.00784314, 0.00784314, ..., 0.03529412, 0.03529412,
#        0.03529412], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32), array([0.16862746, 0.14509805, 0.17254902, ..., 0.10588235, 0.10588235,
#        0.10588235], dtype=float32), array([0.01176471, 0.01176471, 0.01176471, ..., 0.11372549, 0.1254902 ,
#        0.16862746], dtype=float32), array([0.2509804 , 0.24705882, 0.23137255, ..., 0.44705883, 0.44705883,
#        0.41568628], dtype=float32), array([0.        , 0.9098039 , 0.8627451 , ..., 0.05490196, 0.05490196,
#        0.05490196], dtype=float32), array([0.28627452, 0.19607843, 0.26666668, ..., 0.16862746, 0.16078432,
#        0.15686275], dtype=float32), array([0.00392157, 0.        , 0.5803922 , ..., 0.05490196, 0.05490196,
#        0.05882353], dtype=float32), array([0.00784314, 0.00784314, 0.00784314, ..., 0.03529412, 0.03529412,
#        0.03529412], dtype=float32), array([0.2627451 , 0.12156863, 0.09803922, ..., 0.21176471, 0.12941177,
#        0.11764706], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32), array([0.16862746, 0.14509805, 0.17254902, ..., 0.10588235, 0.10588235,
#        0.10588235], dtype=float32), array([0.01176471, 0.01176471, 0.01176471, ..., 0.11372549, 0.1254902 ,
#        0.16862746], dtype=float32), array([0.2509804 , 0.24705882, 0.23137255, ..., 0.44705883, 0.44705883,
#        0.41568628], dtype=float32), array([0.        , 0.9098039 , 0.8627451 , ..., 0.05490196, 0.05490196,
#        0.05490196], dtype=float32), array([0.28627452, 0.19607843, 0.26666668, ..., 0.16862746, 0.16078432,
#        0.15686275], dtype=float32), array([0.00392157, 0.        , 0.5803922 , ..., 0.05490196, 0.05490196,
#        0.05882353], dtype=float32), array([0.00784314, 0.00784314, 0.00784314, ..., 0.03529412, 0.03529412,
#        0.03529412], dtype=float32), array([0.2627451 , 0.12156863, 0.09803922, ..., 0.21176471, 0.12941177,
#        0.11764706], dtype=float32), array([1.       , 0.5568628, 0.5882353, ..., 1.       , 1.       ,
#        1.       ], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32), array([0.16862746, 0.14509805, 0.17254902, ..., 0.10588235, 0.10588235,
#        0.10588235], dtype=float32), array([0.01176471, 0.01176471, 0.01176471, ..., 0.11372549, 0.1254902 ,
#        0.16862746], dtype=float32), array([0.2509804 , 0.24705882, 0.23137255, ..., 0.44705883, 0.44705883,
#        0.41568628], dtype=float32), array([0.        , 0.9098039 , 0.8627451 , ..., 0.05490196, 0.05490196,
#        0.05490196], dtype=float32), array([0.28627452, 0.19607843, 0.26666668, ..., 0.16862746, 0.16078432,
#        0.15686275], dtype=float32), array([0.00392157, 0.        , 0.5803922 , ..., 0.05490196, 0.05490196,
#        0.05882353], dtype=float32), array([0.00784314, 0.00784314, 0.00784314, ..., 0.03529412, 0.03529412,
#        0.03529412], dtype=float32), array([0.2627451 , 0.12156863, 0.09803922, ..., 0.21176471, 0.12941177,
#        0.11764706], dtype=float32), array([1.       , 0.5568628, 0.5882353, ..., 1.       , 1.       ,
#        1.       ], dtype=float32), array([0.        , 0.92941177, 0.7372549 , ..., 0.9882353 , 0.9882353 ,
#        0.9882353 ], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32), array([0.16862746, 0.14509805, 0.17254902, ..., 0.10588235, 0.10588235,
#        0.10588235], dtype=float32), array([0.01176471, 0.01176471, 0.01176471, ..., 0.11372549, 0.1254902 ,
#        0.16862746], dtype=float32), array([0.2509804 , 0.24705882, 0.23137255, ..., 0.44705883, 0.44705883,
#        0.41568628], dtype=float32), array([0.        , 0.9098039 , 0.8627451 , ..., 0.05490196, 0.05490196,
#        0.05490196], dtype=float32), array([0.28627452, 0.19607843, 0.26666668, ..., 0.16862746, 0.16078432,
#        0.15686275], dtype=float32), array([0.00392157, 0.        , 0.5803922 , ..., 0.05490196, 0.05490196,
#        0.05882353], dtype=float32), array([0.00784314, 0.00784314, 0.00784314, ..., 0.03529412, 0.03529412,
#        0.03529412], dtype=float32), array([0.2627451 , 0.12156863, 0.09803922, ..., 0.21176471, 0.12941177,
#        0.11764706], dtype=float32), array([1.       , 0.5568628, 0.5882353, ..., 1.       , 1.       ,
#        1.       ], dtype=float32), array([0.        , 0.92941177, 0.7372549 , ..., 0.9882353 , 0.9882353 ,
#        0.9882353 ], dtype=float32), array([0.9764706 , 0.1764706 , 0.3764706 , ..., 0.49019608, 0.9882353 ,
#        0.9882353 ], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32), array([0.16862746, 0.14509805, 0.17254902, ..., 0.10588235, 0.10588235,
#        0.10588235], dtype=float32), array([0.01176471, 0.01176471, 0.01176471, ..., 0.11372549, 0.1254902 ,
#        0.16862746], dtype=float32), array([0.2509804 , 0.24705882, 0.23137255, ..., 0.44705883, 0.44705883,
#        0.41568628], dtype=float32), array([0.        , 0.9098039 , 0.8627451 , ..., 0.05490196, 0.05490196,
#        0.05490196], dtype=float32), array([0.28627452, 0.19607843, 0.26666668, ..., 0.16862746, 0.16078432,
#        0.15686275], dtype=float32), array([0.00392157, 0.        , 0.5803922 , ..., 0.05490196, 0.05490196,
#        0.05882353], dtype=float32), array([0.00784314, 0.00784314, 0.00784314, ..., 0.03529412, 0.03529412,
#        0.03529412], dtype=float32), array([0.2627451 , 0.12156863, 0.09803922, ..., 0.21176471, 0.12941177,
#        0.11764706], dtype=float32), array([1.       , 0.5568628, 0.5882353, ..., 1.       , 1.       ,
#        1.       ], dtype=float32), array([0.        , 0.92941177, 0.7372549 , ..., 0.9882353 , 0.9882353 ,
#        0.9882353 ], dtype=float32), array([0.9764706 , 0.1764706 , 0.3764706 , ..., 0.49019608, 0.9882353 ,
#        0.9882353 ], dtype=float32), array([0.9764706, 0.1764706, 0.3764706, ..., 0.9882353, 0.9882353,
#        0.9882353], dtype=float32)]
# [array([0.70980394, 0.7176471 , 0.72156864, ..., 0.1254902 , 0.14901961,
#        0.1882353 ], dtype=float32), array([0.3647059 , 0.38039216, 0.47058824, ..., 0.42352942, 0.41960785,
#        0.44705883], dtype=float32), array([0.69803923, 0.40392157, 0.77254903, ..., 0.8039216 , 0.70980394,
#        0.9529412 ], dtype=float32), array([0.7607843 , 0.8117647 , 0.85882354, ..., 0.06666667, 0.05098039,
#        0.07058824], dtype=float32), array([0.6509804 , 0.67058825, 0.7294118 , ..., 0.6117647 , 0.5803922 ,
#        0.6       ], dtype=float32), array([0.7607843 , 0.7372549 , 0.827451  , ..., 0.02745098, 0.01568628,
#        0.09803922], dtype=float32), array([0.        , 0.96862745, 0.7372549 , ..., 0.6862745 , 0.6       ,
#        1.        ], dtype=float32), array([0.8392157 , 0.84313726, 0.84705883, ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.15294118, 0.12941177, 0.50980395, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9411765 , 0.94509804, 0.9490196 , ..., 0.90588236, 0.92941177,
#        0.93333334], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.77254903, 0.78039217,
#        0.76862746], dtype=float32), array([0.47843137, 0.45882353, 0.4745098 , ..., 0.68235296, 0.8784314 ,
#        0.6627451 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.0627451 , 0.15294118, 0.04313726, ..., 0.57254905, 0.04313726,
#        0.02745098], dtype=float32), array([0.16862746, 0.14509805, 0.17254902, ..., 0.10588235, 0.10588235,
#        0.10588235], dtype=float32), array([0.01176471, 0.01176471, 0.01176471, ..., 0.11372549, 0.1254902 ,
#        0.16862746], dtype=float32), array([0.2509804 , 0.24705882, 0.23137255, ..., 0.44705883, 0.44705883,
#        0.41568628], dtype=float32), array([0.        , 0.9098039 , 0.8627451 , ..., 0.05490196, 0.05490196,
#        0.05490196], dtype=float32), array([0.28627452, 0.19607843, 0.26666668, ..., 0.16862746, 0.16078432,
#        0.15686275], dtype=float32), array([0.00392157, 0.        , 0.5803922 , ..., 0.05490196, 0.05490196,
#        0.05882353], dtype=float32), array([0.00784314, 0.00784314, 0.00784314, ..., 0.03529412, 0.03529412,
#        0.03529412], dtype=float32), array([0.2627451 , 0.12156863, 0.09803922, ..., 0.21176471, 0.12941177,
#        0.11764706], dtype=float32), array([1.       , 0.5568628, 0.5882353, ..., 1.       , 1.       ,
#        1.       ], dtype=float32), array([0.        , 0.92941177, 0.7372549 , ..., 0.9882353 , 0.9882353 ,
#        0.9882353 ], dtype=float32), array([0.9764706 , 0.1764706 , 0.3764706 , ..., 0.49019608, 0.9882353 ,
#        0.9882353 ], dtype=float32), array([0.9764706, 0.1764706, 0.3764706, ..., 0.9882353, 0.9882353,
#        0.9882353], dtype=float32), array([0.46666667, 0.94509804, 0.9647059 , ..., 1.        , 1.        ,
# ...
#        0.10588235], dtype=float32), array([0.01176471, 0.01176471, 0.01176471, ..., 0.11372549, 0.1254902 ,
#        0.16862746], dtype=float32), array([0.2509804 , 0.24705882, 0.23137255, ..., 0.44705883, 0.44705883,
#        0.41568628], dtype=float32), array([0.        , 0.9098039 , 0.8627451 , ..., 0.05490196, 0.05490196,
#        0.05490196], dtype=float32), array([0.28627452, 0.19607843, 0.26666668, ..., 0.16862746, 0.16078432,
#        0.15686275], dtype=float32), array([0.00392157, 0.        , 0.5803922 , ..., 0.05490196, 0.05490196,
#        0.05882353], dtype=float32), array([0.00784314, 0.00784314, 0.00784314, ..., 0.03529412, 0.03529412,
#        0.03529412], dtype=float32), array([0.2627451 , 0.12156863, 0.09803922, ..., 0.21176471, 0.12941177,
#        0.11764706], dtype=float32), array([1.       , 0.5568628, 0.5882353, ..., 1.       , 1.       ,
#        1.       ], dtype=float32), array([0.        , 0.92941177, 0.7372549 , ..., 0.9882353 , 0.9882353 ,
#        0.9882353 ], dtype=float32), array([0.9764706 , 0.1764706 , 0.3764706 , ..., 0.49019608, 0.9882353 ,
#        0.9882353 ], dtype=float32), array([0.9764706, 0.1764706, 0.3764706, ..., 0.9882353, 0.9882353,
#        0.9882353], dtype=float32), array([0.46666667, 0.94509804, 0.9647059 , ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.99215686, 1.        , 1.        , ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.47058824, 0.47058824, 0.48235294, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([0.09019608, 0.09019608, 0.8509804 , ..., 0.16862746, 0.16862746,
#        0.16470589], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.50980395, 0.48235294, 0.5058824 , ..., 0.12941177, 0.39215687,
#        0.04313726], dtype=float32), array([0.95686275, 0.95686275, 0.95686275, ..., 0.93333334, 0.9411765 ,
#        0.94509804], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.8392157, 0.8392157, 0.8392157, ..., 1.       , 1.       ,
#        1.       ], dtype=float32), array([0.9137255 , 0.92156863, 0.9254902 , ..., 0.9764706 , 0.9647059 ,
#        0.9647059 ], dtype=float32), array([0.99607843, 0.99215686, 1.        , ..., 0.6117647 , 0.6627451 ,
#        0.6784314 ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.92941177, 0.93333334, 0.9411765 , ..., 0.9137255 , 0.9137255 ,
#        0.90588236], dtype=float32), array([0.6784314 , 0.63529414, 0.5647059 , ..., 0.8980392 , 0.8627451 ,
#        0.81960785], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.24313726, 0.21960784,
#        0.24313726], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.3372549 , 0.5568628 , 0.8901961 , ..., 0.20784314, 0.21960784,
#        0.21960784], dtype=float32), array([0.19215687, 0.18039216, 0.16078432, ..., 0.3529412 , 0.5568628 ,
#        0.1882353 ], dtype=float32), array([0.9137255 , 0.99607843, 0.9411765 , ..., 0.4862745 , 0.6666667 ,
#        0.7490196 ], dtype=float32), array([0.87058824, 0.8784314 , 0.6509804 , ..., 0.6156863 , 0.6627451 ,
#        0.7490196 ], dtype=float32), array([0.6313726 , 0.6901961 , 0.8980392 , ..., 0.23137255, 0.27450982,
#        0.24313726], dtype=float32), array([0.90588236, 0.79607844, 0.8392157 , ..., 0.627451  , 0.627451  ,
#        0.8156863 ], dtype=float32), array([0.85490197, 0.85882354, 0.8627451 , ..., 0.80784315, 0.80784315,
#        0.80784315], dtype=float32), array([0.24705882, 0.25882354, 0.2784314 , ..., 0.24705882, 0.23137255,
#        0.20784314], dtype=float32), array([0.5803922 , 0.5764706 , 0.5764706 , ..., 0.43529412, 0.3764706 ,
#        0.32156864], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.53333336, 0.54901963,
#        0.56078434], dtype=float32), array([0.6117647 , 0.6627451 , 0.69803923, ..., 0.65882355, 0.6901961 ,
#        0.7058824 ], dtype=float32), array([0.14117648, 0.14509805, 0.14901961, ..., 0.7137255 , 0.9254902 ,
#        0.92941177], dtype=float32), array([1.        , 0.9882353 , 0.99215686, ..., 0.54509807, 1.        ,
#        1.        ], dtype=float32), array([1.        , 0.99215686, 0.99215686, ..., 0.8156863 , 0.8156863 ,
#        0.81960785], dtype=float32), array([0.98039216, 1.        , 0.99215686, ..., 0.45490196, 0.41568628,
#        0.3529412 ], dtype=float32), array([0.93333334, 0.92941177, 0.98039216, ..., 0.40392157, 0.34117648,
#        0.25490198], dtype=float32), array([0.32941177, 0.26666668, 0.20784314, ..., 0.1254902 , 0.12941177,
#        0.12156863], dtype=float32), array([0.42745098, 0.39215687, 0.36862746, ..., 0.88235295, 0.7490196 ,
#        0.52156866], dtype=float32), array([0.48235294, 0.5058824 , 0.4862745 , ..., 0.59607846, 0.5764706 ,
#        0.42745098], dtype=float32), array([1.       , 1.       , 1.       , ..., 0.5882353, 0.5882353,
#        0.5686275], dtype=float32), array([0.5372549 , 0.54901963, 0.56078434, ..., 0.42352942, 0.39607844,
#        0.34117648], dtype=float32), array([0.7529412 , 0.9254902 , 1.        , ..., 0.7019608 , 0.45490196,
#        0.74509805], dtype=float32), array([1.        , 1.        , 1.        , ..., 1.        , 1.        ,
#        0.99607843], dtype=float32), array([0.13725491, 0.13725491, 0.13333334, ..., 0.14117648, 0.13725491,
#        0.1254902 ], dtype=float32), array([0.85882354, 0.8352941 , 0.81960785, ..., 0.5803922 , 0.4862745 ,
#        0.3764706 ], dtype=float32), array([0.30980393, 0.99607843, 0.99607843, ..., 0.8666667 , 0.7254902 ,
#        0.78039217], dtype=float32), array([0.9607843 , 0.7529412 , 0.92941177, ..., 0.15686275, 0.3647059 ,
#        0.19215687], dtype=float32), array([0.5647059 , 0.6862745 , 0.69803923, ..., 0.79607844, 0.8       ,
#        0.7254902 ], dtype=float32), array([0.23529412, 0.46666667, 0.48235294, ..., 0.23137255, 0.13725491,
#        0.13725491], dtype=float32), array([0.5529412 , 0.23137255, 0.16470589, ..., 0.18431373, 0.17254902,
#        0.18039216], dtype=float32), array([0.8392157 , 0.83137256, 0.84705883, ..., 0.87058824, 0.8392157 ,
#        0.8509804 ], dtype=float32), array([0.21960784, 0.40784314, 0.16078432, ..., 0.3647059 , 0.5372549 ,
#        0.46666667], dtype=float32), array([0.9411765 , 0.94509804, 0.95686275, ..., 0.9647059 , 0.9647059 ,
#        0.9529412 ], dtype=float32), array([0.85490197, 0.80784315, 0.64705884, ..., 0.7490196 , 0.75686276,
#        0.78431374], dtype=float32), array([0.3647059 , 0.33333334, 0.32941177, ..., 0.31764707, 0.21960784,
#        0.16862746], dtype=float32), array([0.85882354, 0.87058824, 0.8745098 , ..., 0.9529412 , 0.94509804,
#        0.9411765 ], dtype=float32), array([0.45882353, 0.53333336, 0.34901962, ..., 0.11764706, 0.        ,
#        0.01960784], dtype=float32), array([0.9607843 , 0.7647059 , 0.93333334, ..., 0.15294118, 0.36078432,
#        0.16470589], dtype=float32), array([0.1764706 , 0.20784314, 0.1882353 , ..., 0.15686275, 0.18039216,
#        0.30588236], dtype=float32), array([0.99215686, 0.9843137 , 0.98039216, ..., 0.91764706, 0.92941177,
#        0.9764706 ], dtype=float32), array([0.08235294, 0.16078432, 0.11372549, ..., 0.90588236, 0.6431373 ,
#        0.73333335], dtype=float32), array([0.627451  , 0.45490196, 0.59607846, ..., 0.40392157, 0.3372549 ,
#        0.10980392], dtype=float32), array([0.17254902, 0.10980392, 0.07450981, ..., 0.19607843, 0.00784314,
#        0.        ], dtype=float32), array([0.89411765, 0.2784314 , 0.10196079, ..., 0.78431374, 0.7607843 ,
#        0.74509805], dtype=float32), array([0.7058824 , 0.5372549 , 0.7411765 , ..., 0.30588236, 0.1764706 ,
#        0.57254905], dtype=float32), array([0.16470589, 0.79607844, 0.6901961 , ..., 0.5803922 , 0.4392157 ,
#        0.5764706 ], dtype=float32), array([0.827451  , 0.84313726, 0.8156863 , ..., 0.5294118 , 0.5176471 ,
#        0.5764706 ], dtype=float32), array([0.5254902, 0.6392157, 0.5921569, ..., 0.9764706, 0.9764706,
#        0.9764706], dtype=float32), array([0.34509805, 0.41568628, 0.5764706 , ..., 0.18431373, 0.19607843,
#        0.18039216], dtype=float32), array([0.42745098, 0.4862745 , 0.54509807, ..., 0.654902  , 0.6862745 ,
#        0.69411767], dtype=float32), array([0.4392157 , 0.45882353, 0.47058824, ..., 0.43137255, 0.48235294,
#        0.34509805], dtype=float32), array([0.94509804, 1.        , 0.94509804, ..., 0.95686275, 0.9647059 ,
#        0.9843137 ], dtype=float32), array([0.827451  , 0.8392157 , 0.83137256, ..., 0.17254902, 0.19607843,
#        0.96862745], dtype=float32), array([1.        , 0.99607843, 1.        , ..., 0.15686275, 0.10588235,
#        0.05490196], dtype=float32), array([0.9529412 , 0.12941177, 0.08627451, ..., 0.03137255, 0.01568628,
#        0.01176471], dtype=float32), array([0.7058824 , 0.6784314 , 0.6117647 , ..., 0.4392157 , 0.42352942,
#        0.40392157], dtype=float32), array([0.19215687, 0.2       , 0.20784314, ..., 0.14117648, 0.17254902,
#        0.1882353 ], dtype=float32), array([0.23921569, 0.2       , 0.23529412, ..., 0.21568628, 0.5058824 ,
#        0.60784316], dtype=float32), array([0.89411765, 0.9019608 , 0.9098039 , ..., 0.7490196 , 0.56078434,
#        0.54901963], dtype=float32), array([0.99607843, 0.99215686, 0.99607843, ..., 0.5921569 , 0.827451  ,
#        0.94509804], dtype=float32), array([0.03529412, 0.03529412, 0.07450981, ..., 0.972549  , 0.9529412 ,
#        0.972549  ], dtype=float32), array([0.9411765 , 0.99607843, 0.99607843, ..., 0.49803922, 0.5529412 ,
#        0.56078434], dtype=float32), array([0.99607843, 0.7019608 , 0.5568628 , ..., 0.74509805, 0.70980394,
#        0.8901961 ], dtype=float32), array([0.07843138, 0.36078432, 0.41960785, ..., 0.03529412, 0.03529412,
#        0.02745098], dtype=float32), array([0.09411765, 0.08627451, 0.08627451, ..., 0.38431373, 0.3137255 ,
#        0.24313726], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.9411765 , 0.77254903,
#        0.79607844], dtype=float32), array([0.68235296, 0.8       , 0.94509804, ..., 0.46666667, 0.6431373 ,
#        0.6745098 ], dtype=float32), array([0.8666667 , 0.85882354, 0.90588236, ..., 0.32941177, 0.27058825,
#        0.32156864], dtype=float32), array([0.8627451 , 0.8627451 , 0.8666667 , ..., 0.20784314, 0.4509804 ,
#        0.54509807], dtype=float32), array([0.43529412, 0.68235296, 0.8039216 , ..., 0.4745098 , 0.5411765 ,
#        0.34117648], dtype=float32), array([0.        , 0.03529412, 0.01960784, ..., 0.00784314, 0.01960784,
#        0.02352941], dtype=float32), array([0.8235294 , 0.7921569 , 0.8235294 , ..., 0.13725491, 0.11764706,
#        0.18431373], dtype=float32), array([0.9529412 , 0.94509804, 0.94509804, ..., 0.2627451 , 0.2509804 ,
#        0.26666668], dtype=float32), array([0.654902  , 0.7294118 , 0.7411765 , ..., 0.87058824, 0.9098039 ,
#        0.89411765], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.5529412 , 0.24705882,
#        0.7019608 ], dtype=float32), array([0.27058825, 0.32156864, 0.22352941, ..., 0.3019608 , 0.29411766,
#        0.3372549 ], dtype=float32), array([0.22745098, 0.1764706 , 0.16862746, ..., 0.09803922, 0.04705882,
#        0.08235294], dtype=float32), array([0.78039217, 0.8117647 , 0.8       , ..., 0.8980392 , 0.90588236,
#        0.9137255 ], dtype=float32), array([0.81960785, 0.81960785, 0.81960785, ..., 0.7921569 , 0.4745098 ,
#        0.23137255], dtype=float32), array([0.21960784, 0.32156864, 0.33333334, ..., 0.8117647 , 0.7490196 ,
#        0.78039217], dtype=float32), array([0.98039216, 0.9843137 , 0.99607843, ..., 0.13725491, 0.11764706,
#        0.11764706], dtype=float32), array([0.48235294, 0.45490196, 0.5137255 , ..., 0.8156863 , 0.7137255 ,
#        0.654902  ], dtype=float32), array([0.3882353 , 0.42352942, 0.41960785, ..., 0.6745098 , 0.7019608 ,
#        0.7137255 ], dtype=float32), array([0.78431374, 0.76862746, 0.7176471 , ..., 0.9019608 , 0.89411765,
#        0.8784314 ], dtype=float32), array([0.26666668, 0.32156864, 0.35686275, ..., 0.5882353 , 0.5568628 ,
#        0.29411766], dtype=float32), array([0.49411765, 0.49019608, 0.5137255 , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.92156863, 0.9372549 , 0.94509804, ..., 0.8901961 , 0.89411765,
#        0.89411765], dtype=float32), array([0.94509804, 0.95686275, 0.95686275, ..., 0.89411765, 0.8901961 ,
#        0.90588236], dtype=float32), array([0.42352942, 0.49019608, 0.78431374, ..., 0.10196079, 0.03921569,
#        0.07450981], dtype=float32), array([0.9137255 , 0.9098039 , 0.92156863, ..., 0.8235294 , 0.36862746,
#        0.8901961 ], dtype=float32), array([0.96862745, 1.        , 0.99215686, ..., 0.10588235, 0.0627451 ,
#        0.16078432], dtype=float32), array([1.        , 1.        , 1.        , ..., 0.8156863 , 0.75686276,
#        0.5686275 ], dtype=float32), array([0.58431375, 0.6       , 0.5921569 , ..., 0.40392157, 0.39215687,
#        0.43529412], dtype=float32), array([0.58431375, 0.59607846, 0.60784316, ..., 0.83137256, 0.8039216 ,
#        0.8117647 ], dtype=float32), array([0.37254903, 0.10196079, 0.3882353 , ..., 0.25882354, 0.12941177,
#        0.01568628], dtype=float32), array([0.9137255 , 0.93333334, 0.92941177, ..., 0.5803922 , 0.4       ,
#        0.4117647 ], dtype=float32), array([0.99607843, 0.4862745 , 0.99607843, ..., 0.14509805, 0.23137255,
#        0.56078434], dtype=float32), array([0.1764706 , 0.11372549, 0.07843138, ..., 0.21960784, 0.01176471,
#        0.        ], dtype=float32), array([0.7411765 , 0.7529412 , 0.7529412 , ..., 0.44313726, 0.81960785,
#        0.83137256], dtype=float32), array([0.2627451 , 0.22745098, 0.23137255, ..., 0.60784316, 0.59607846,
#        0.6627451 ], dtype=float32), array([0.53333336, 0.45882353, 0.36862746, ..., 0.47058824, 0.20784314,
#        0.21960784], dtype=float32), array([0.9764706 , 0.9843137 , 1.        , ..., 0.21568628, 0.20784314,
#        0.07450981], dtype=float32), array([0.9137255, 0.9137255, 0.9137255, ..., 0.8666667, 0.8784314,
#        0.8862745], dtype=float32), array([0.94509804, 0.91764706, 0.95686275, ..., 0.5372549 , 0.25490198,
#        0.28235295], dtype=float32), array([0.18039216, 0.2784314 , 0.31764707, ..., 0.2901961 , 0.5372549 ,
#        0.42745098], dtype=float32), array([0.06666667, 0.06666667, 0.07843138, ..., 0.76862746, 0.01960784,
#        0.00392157], dtype=float32), array([0.01176471, 0.05490196, 0.08627451, ..., 0.6784314 , 0.75686276,
#        0.01176471], dtype=float32), array([0.01960784, 0.03529412, 0.10980392, ..., 0.09019608, 0.05098039,
#        0.0627451 ], dtype=float32), array([0.9764706 , 0.9764706 , 0.98039216, ..., 0.95686275, 0.95686275,
#        0.9254902 ], dtype=float32), array([0.6627451 , 0.63529414, 0.6392157 , ..., 0.5254902 , 0.7019608 ,
#        0.72156864], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.5411765 , 0.54901963,
#        0.6745098 ], dtype=float32), array([0.8117647 , 0.6392157 , 0.5568628 , ..., 0.04705882, 0.04705882,
#        0.05882353], dtype=float32), array([0.2       , 0.23529412, 0.32156864, ..., 0.32156864, 0.40392157,
#        0.4627451 ], dtype=float32), array([0.8745098 , 0.8745098 , 0.8784314 , ..., 0.4745098 , 0.54509807,
#        0.7019608 ], dtype=float32), array([0.85490197, 0.84705883, 0.8627451 , ..., 0.7176471 , 0.68235296,
#        0.60784316], dtype=float32), array([0.01568628, 0.01176471, 0.00784314, ..., 0.4117647 , 0.41960785,
#        0.38039216], dtype=float32), array([0.1254902 , 0.13333334, 0.09803922, ..., 0.12941177, 0.12156863,
#        0.11764706], dtype=float32), array([0.09019608, 0.09803922, 0.06666667, ..., 0.9647059 , 0.95686275,
#        0.95686275], dtype=float32), array([0.63529414, 0.6784314 , 0.4745098 , ..., 0.05490196, 0.04313726,
#        0.04705882], dtype=float32)]

# %%
# kerasに渡すためにnumpy配列に変換
image_list = np.array(image_list)
# ラベルの配列を1と0からなるラベル配列に変更
# 0 -> [1,0], 1 -> [0,1] という感じ。
Y = to_categorical(label_list)

# %%
# モデルを生成してニューラルネットを構築
model = Sequential()
model.add(Dense(200, input_dim=1875))
model.add(Activation("relu"))
model.add(Dropout(0.2))

model.add(Dense(200))
model.add(Activation("relu"))
model.add(Dropout(0.2))

model.add(Dense(2))
model.add(Activation("softmax"))

# %%
# オプティマイザにAdamを使用
opt = Adam()
# モデルをコンパイル
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
# 学習を実行。10%はテストに使用。
model.fit(image_list, Y, nb_epoch=1500, batch_size=100, validation_split=0.1)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-aada38cd0ac3> in <module>
#       4 model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
#       5 # 学習を実行。10%はテストに使用。
# ----> 6 model.fit(image_list, Y, nb_epoch=1500, batch_size=100, validation_split=0.1)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1152             sample_weight=sample_weight,
#    1153             class_weight=class_weight,
# -> 1154             batch_size=batch_size)
#    1155
#    1156         # Prepare validation data.
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     577             feed_input_shapes,
#     578             check_batch_axis=False,  # Don't enforce the batch size.
# --> 579             exception_prefix='input')
#     580
#     581         if y is not None:
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     143                             ': expected ' + names[i] + ' to have shape ' +
#     144                             str(shape) + ' but got array with shape ' +
# --> 145                             str(data_shape))
#     146     return data
#     147
#
# ValueError: Error when checking input: expected dense_1_input to have shape (1875,) but got array with shape (1,)

# %%
# テスト用ディレクトリ(./data/train/)の画像でチェック。正解率を表示する。
total = 0.
ok_count = 0.

# %%
for dir in os.listdir("C:/Users/user/Desktop/test"):
    dir1 = "C:/Users/user/Desktop/test/" + dir 
    label = 0

    if dir == "テスト用りんご画像":
        label = 0
    elif dir == "テスト用梨画像":
        label = 1

    for file in os.listdir(dir1):
        label_list.append(label)
        filepath = dir1 + "/" + file
        image = np.array(Image.open(filepath).resize((25, 25)))
        print(filepath)
        image = image.transpose(2, 0, 1)
        image = image.reshape(1, image.shape[0] * image.shape[1] * image.shape[2]).astype("float32")[0]
        result = model.predict_classes(np.array([image / 255.]))
        print("label:", label, "result:", result[0])

        total += 1.

        if label == result[0]:
            ok_count += 1.
            
        if result[0]:
            new_path = shutil.move(filepath, 'C:/Users/user/Desktop/apple')
        else:
            pass

print("正解率: ", ok_count / total * 100, "%")
# Out:
# C:/Users/user/Desktop/test/テスト用りんご画像/images (1).jpg
# label: 0 result: 0
# C:/Users/user/Desktop/test/テスト用りんご画像/images.jpg
# label: 0 result: 0
# C:/Users/user/Desktop/test/テスト用りんご画像/ダウンロード (11).jpg
# label: 0 result: 0
# C:/Users/user/Desktop/test/テスト用りんご画像/ダウンロード (12).jpg
# label: 0 result: 0
# C:/Users/user/Desktop/test/テスト用りんご画像/ダウンロード (13).jpg
# label: 0 result: 1
# C:/Users/user/Desktop/test/テスト用梨画像/images (1)1.jpg
# label: 1 result: 1
# C:/Users/user/Desktop/test/テスト用梨画像/images (2)3.jpg
# label: 1 result: 1
# C:/Users/user/Desktop/test/テスト用梨画像/images (3)5.jpg
# label: 1 result: 1
# C:/Users/user/Desktop/test/テスト用梨画像/images555.jpg
# label: 1 result: 1
# C:/Users/user/Desktop/test/テスト用梨画像/ダウンロード (9)66.jpg
# label: 1 result: 1
# 正解率:  83.87096774193549 %
